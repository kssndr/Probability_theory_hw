# %% [markdown]
# # Урок 4. Непрерывные случайные величины. Функция распределения и плотность распределения вероятностей. Равномерное и нормальное распределение. Центральная предельная теорема

# %% [markdown]
# ## 1. Случайная непрерывная величина A имеет равномерное распределение на промежутке (200, 800]. Найдите ее среднее значение и дисперсию.

# %% [markdown]
# Математическое ожидание $M(X)$ равномерно распределенной непрерывной случайной величины можно вычислить по формуле:
# $$M(X) = \frac{a + b}{2}=\frac{200+800}{2}<500$$

# %% [markdown]
# Дисперсия $D(X)$:
# $$D(X) = \frac{(b - a)^2}{12}=\frac{(800-200)^2}{12}=\frac{360000}{12}<30000$$

# %% [markdown]
# ## 2. О случайной непрерывной равномерно распределенной величине B известно, что ее дисперсия равна 0.2.  Можно ли найти правую границу величины B и ее среднее значение зная, что левая граница равна 0.5? Если да, найдите ее.

# %% [markdown]
# Дисперсия $D(X)$:
# $$D(X) = \frac{(b - a)^2}{12}=\frac{(b-0.5)^2}{12}=0.2$$
# $$(b-0.5)^2=0.2\dot12$$
# $$b=\pm\sqrt{2.4}+0.5$$
# $$b=\sqrt{2.4}+0.5=2.05$$
# $$(потому \ что \ это \ правая \ граница)$$

# %% [markdown]
# $$M(X) = \frac{a + b}{2}=\frac{0.5+2.05}{2}=1.25$$

# %% [markdown]
# ## 3. Непрерывная случайная величина X распределена нормально и задана плотностью распределения
# ## $$f(x) = \cfrac{1}{4\sqrt{2\pi}}e^{-\frac{(x+2)^{2}}{32}}$$
# ## Найдите:
# ## а). M(X)
# ## б). D(X)
# ## в). std(X) (среднее квадратичное отклонение)

# %% [markdown]
# Из формулы плотности вероятности:
# $$f(x) = \cfrac{1}{\sigma\sqrt{2\pi}}e^{-\frac{(x-a)^{2}}{2\sigma}}$$
# Мы находим:
# a) Математическое ожидание - среднее значение случайной величины $𝑀(𝑋)$
# $$M(X)=a=-2$$
# б) Дисперсия степень рассеяности случайной величины относительно мат ожидания - $D(X)$:
# $$D(X)=\sigma^2=\frac{32}{2}=16$$
# в) std(X) (среднее квадратичное отклонение):
# $$\sigma = 4$$

# %% [markdown]
# ## 4. Рост взрослого населения города X имеет нормальное распределение.
# ## Причем, средний рост равен 174 см, а среднее квадратичное отклонение равно 8 см.
# ## Какова вероятность того, что случайным образом выбранный взрослый человек имеет рост:
# ## а). больше 182 см
# ## б). больше 190 см
# ## в). от 166 см до 190 см
# ## г). от 166 см до 182 см
# ## д). от 158 см до 190 см
# ## е). не выше 150 см или не ниже 190 см
# ## ё). не выше 150 см или не ниже 198 см
# ## ж). ниже 166 см.

# %% [markdown]
# ### а). больше 182 см
# 182см это граница первой и второй квартилей - значит вероятность, что случайным образом выбранный взрослый человекимеет рост больше 190см, **меньше 16%** (100-68)/2

# %% [markdown]
# ### б). больше 190 см
# 190см это граница второй и третьей квартилей - значит вероятность, что случайным образом выбранный взрослый человекимеет рост больше 190см, **меньше 2.3%** (100-95.4)/2

# %% [markdown]
# ### б). от 166 см до 190 см
# это в граница от втрой квартильи слева до третьей квартили справа, вероятность составит 95.4 - (95.4-68)/2 = **81.7%**

# %% [markdown]
# ### г). от 166 см до 182 см
# вероятность **68%**

# %% [markdown]
# ### д). от 158 см до 190 см
# вероятность **95.4%**

# %% [markdown]
# ### е). не выше 150 см или не ниже 190 см
# вероятность **2.44%** (100-
# 99.72)/2 + (100-95.4)/2

# %% [markdown]
# ### ё). не выше 150 см или не ниже 198 см
# вероятность **0.28%** (100-99.72)

# %% [markdown]
# ### ж). ниже 166 см.
#
# вероятность **16%**(100-68)/2

# %% [markdown]
# ## 5. На сколько сигм (средних квадратичных отклонений) отклоняется рост человека, равный 190 см, от математического ожидания роста в популяции, в которой M(X) = 178 см и D(X) = 25 кв.см?

# %% [markdown]
# $\sigma=\sqrt{\sigma}=\sqrt{D(X)}=\sqrt{25}=5$
# $\frac{190-170}{5}=\frac{20}{5}=4$
# отклонение состовляет 4 $\sigma$
